# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## AJAY CHAKHALIYA
# 100% HUMAN

# %% [markdown]
# I AM INTRESTED IN DATA SCIENCE BECAUSE I LOVE TO GAIN INSIGHTS FROM DATA

# %% [markdown]
# ### THE FOLLOWING TEST THE GAUSS FORMULA

# %%
def gauss(n):
    return (n*(n+1))/2
gauss(100)== sum(range(101))
# Out:
# True

# %% [raw]
# . one
# . two
# . three
# . one
# . two
# . three
